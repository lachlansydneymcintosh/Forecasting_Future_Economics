# %% [markdown]
# # **Computational General Equilibrium Modelling**
# Modelling methods are derived, adapted, and inspired from a working discussion paper 'General Equilibrium Gravity Modeling in Python' by Peter R. Harman under the U.S. International Trade Commission (USITC). Note that an older version of scipy is being
# (https://www.usitc.gov/publications/332/working_papers/herman_2021_gegravity_modeling_in_python.pdf)

# %%
# Packages
# import gme as gme
import gegravity as ge
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Packages
#       2 # import gme as gme
# ----> 3 import gegravity as ge
#       4 import pandas as pd
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gegravity\__init__.py:1
# ----> 1 from .OneSectorGE import *
#       2 from .BaselineData import *
#       3 from .MonteCarloGE import * # move these to after comments to produce documentation. Not sure if that affects packaging.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gegravity\OneSectorGE.py:14
#      12 import pandas as pd
#      13 from pandas import DataFrame
# ---> 14 from gme.estimate.EstimationModel import EstimationModel
#      15 from .BaselineData import BaselineData
#      16 from scipy.optimize import root
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gme\__init__.py:6
# ...
